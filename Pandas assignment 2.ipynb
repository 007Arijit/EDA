# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\wwwko\Downloads\task -20220731T125958Z-001\task\FitBit data.csv')
df.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
# 5  1503960366    3/30/2016       10970           7.16             7.16
# 6  1503960366    3/31/2016       12256           7.86             7.86
# 7  1503960366     4/1/2016       12262           7.87             7.87
# 8  1503960366     4/2/2016       11248           7.25             7.25
# 9  1503960366     4/3/2016       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# ...

# %%
##convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
ADate=pd.to_datetime(df['ActivityDate'])

# %%
type(ADate[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#Find out in this data that how many unique id's we have

df['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
#which id is one of the active id that you have in whole dataset

df['Total_active_minutes']=df['VeryActiveMinutes']+df['FairlyActiveMinutes']+df['LightlyActiveMinutes']
df.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
# 5  1503960366    3/30/2016       10970           7.16             7.16
# 6  1503960366    3/31/2016       12256           7.86             7.86
# 7  1503960366     4/1/2016       12262           7.87             7.87
# 8  1503960366     4/2/2016       11248           7.25             7.25
# 9  1503960366     4/3/2016       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# ...

# %%
Active_Id=df.groupby('Id')['Total_active_minutes'].sum()
Active_Id.nlargest(1)
# Out:
# Id
# 1503960366    5318
# Name: Total_active_minutes, dtype: int64

# %%
#Find out who is the laziest person id that we have in dataset

Laziest=df.groupby('Id')['SedentaryMinutes'].sum()
Laziest.nlargest(1)
# Out:
# Id
# 4057192912    43458
# Name: SedentaryMinutes, dtype: int64

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#Find out in this data that how many unique id's we have

df['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
#how many of them have not logged there activity find out in terms of number of ids

Not_logged=df[df.LoggedActivitiesDistance == 0]

# %%
Not_logged['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
Not_logged=Not_logged.groupby('Id').count()
Not_logged
# Out:
#             ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 1503960366             1           1              1                1
# 1624580081             1           1              1                1
# 1644430081             1           1              1                1
# 1844505072             1           1              1                1
# 1927972279             1           1              1                1
# 2022484408             1           1              1                1
# 2026352035             1           1              1                1
# 2320127002             1           1              1                1
# 2347167796             1           1              1                1
# 2873212765             1           1              1                1
# 2891001357             1           1              1                1
# 3372868164             1           1              1                1
# ...

# %%
len(Not_logged.LoggedActivitiesDistance)
# Out:
# 35

# %%
Logged=df[df.LoggedActivitiesDistance != 0]
Logged
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 138  2891001357     4/1/2016           0           0.00             0.00
# 139  2891001357     4/2/2016        4126           3.22             0.00
# 142  2891001357     4/5/2016        2063           1.61             0.00
# 215  4057192912    3/30/2016        5419           4.00             4.57
# 335  6391747486     4/2/2016        2101           2.03             0.00
# 338  6391747486     4/5/2016        9766           7.51             0.78
# 359  6962181067     4/6/2016       12480           8.86             8.25
# 360  6962181067     4/7/2016       13417           9.65             8.87
# 361  6962181067     4/8/2016       14400          10.88             9.52
# 364  6962181067    4/11/2016       12362           9.09             8.17
# 366  7007744171     4/1/2016       11680           9.06             7.81
# 369  7007744171     4/4/2016       15266          11.40            10.21
# ...

# %%
Logged=Logged.groupby('Id').count()
Logged
# Out:
#             ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 2891001357             3           3              3                3
# 4057192912             1           1              1                1
# 6391747486             2           2              2                2
# 6962181067             4           4              4                4
# 7007744171             7           7              7                7
# 8378563200             7           7              7                7
#
#             LoggedActivitiesDistance  VeryActiveDistance  \
# Id
# 2891001357                         3                   3
# 4057192912                         1                   1
# 6391747486                         2                   2
# 6962181067                         4                   4
# 7007744171                         7                   7
# 8378563200                         7                   7
#
#             ModeratelyActiveDistance  LightActiveDistance  \
# Id
# ...

# %%
len(Logged.ActivityDate)
# Out:
# 6

# %%
#Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

Healthy_Person=df.groupby('Id').sum()
Healthy_Person[Healthy_Person['Calories']>=2500]
Healthy_Person
# Out:
#             TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 1503960366      221170     144.540001       144.540001
# 1624580081       80299      52.189999        52.189999
# 1644430081       92748      67.490000        67.490000
# 1844505072       43687      28.880000        28.880000
# 1927972279       26170      18.130000        18.130000
# 2022484408      146099     105.290001       105.290001
# 2026352035       40713      25.240000        25.240000
# 2320127002       37661      25.470000        25.470000
# 2347167796      147001      97.670001        97.670001
# 2873212765       79639      53.630001        53.630001
# 2891001357        6189       4.830000         0.000000
# 3372868164       61275      42.160000        42.160000
# 3977333714      103967      69.679999        69.679999
# 4020332650      184851     132.600000       132.600000
# 4057192912       60391      44.450000        45.020000
# 4319703577       93847      63.070000        63.070000
# ...

# %%
len(Healthy_Person.Calories)   #healthy person we have in our dataset
# Out:
# 35

# %%
#what is a totla acumulative calories burn for a person find out

Most_Calori_Burner=df.groupby('Id')['Calories'].sum()
Most_Calori_Burner
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64

# %%
Most_Calori_Burner.nlargest(1)
# Out:
# Id
# 4020332650    98412
# Name: Calories, dtype: int64

# %%
type(Most_Calori_Burner)
# Out:
# pandas.core.series.Series

# %%
#who is the third most active person in this dataset find out those in pandas and in sql both

Most_Calori_Burner.nlargest(3)
# Out:
# Id
# 4020332650    98412
# 4057192912    60913
# 4702921684    42322
# Name: Calories, dtype: int64

# %%
Most_Calori_Burner.sort_values(ascending=False).reset_index().iloc[2]
# Out:
# Id          4702921684
# Calories         42322
# Name: 2, dtype: int64

# %%
#who is the 5th most laziest person avilable in dataset find it out

Laziest.nlargest(5)
# Out:
# Id
# 4057192912    43458
# 4020332650    34663
# 1624580081    24288
# 8253242879    16228
# 1503960366    15387
# Name: SedentaryMinutes, dtype: int64

# %%
Laziest.sort_values(ascending=False).reset_index().iloc[4]
# Out:
# Id                  1503960366
# SedentaryMinutes         15387
# Name: 4, dtype: int64
