# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\wwwko\Downloads\task -20220731T125958Z-001\task\Superstore_USA.xlsx')
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df1=pd.read_excel(r'C:\Users\wwwko\Downloads\task -20220731T125958Z-001\task\Superstore_USA.xlsx', sheet_name="Returns")
df1
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
df3=pd.concat([df,df1], axis=1)  #try  to join order and return data both in sql and pandas
df3
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df3.groupby('Row ID')['Status'].count()
# Out:
# Row ID
# 2        0
# 27       0
# 52       0
# 53       0
# 62       0
#         ..
# 26395    1
# 26396    1
# 26397    1
# 26398    0
# 26399    0
# Name: Status, Length: 9426, dtype: int64

# %%
df3['Customer ID'].unique()
# Out:
# array([   2,    3,    5, ..., 3400, 3402, 3403], dtype=int64)

# %%
df3[df3['Status'] == "Returned"][["Customer ID", "Customer Name"]].drop_duplicates() #Find out how return that we ahve recived and with a product id
# Out:
#       Customer ID    Customer Name
# 0               2  Janice Fletcher
# 1               3    Bonnie Potter
# 7               5   Ronnie Proctor
# 9               6     Dwight Hwang
# 13              7        Leon Gill
# ...           ...              ...
# 1623          613   Lynda Martinez
# 1626          614    Ricky Kaufman
# 1630          615   Steven Herring
# 1631          617    Brett Schultz
# 1633          618     Robert Cowan
#
# [500 rows x 2 columns]

# %%
Unique_Cust=df3['Customer Name'].unique()   #Try to find out how many unique customer that we have

# %%
type(Unique_Cust)
# Out:
# numpy.ndarray

# %%
len(Unique_Cust)
# Out:
# 2703

# %%
df3['Ship Mode'].unique()   #find out how many different differnet shipement mode that we have and
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
Per_ship_mode=(df3.groupby('Ship Mode')['Ship Mode'].count()/len(df3)*100) # what is a percentage usablity of all the shipment mode with respect to dataset
Per_ship_mode
# Out:
# Ship Mode
# Delivery Truck    13.611288
# Express Air       11.744112
# Regular Air       74.644600
# Name: Ship Mode, dtype: float64

# %%
df3.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
df3['Transction Date']=df3['Ship Date']-df3['Order Date']   #Create a new coulmn and try to find our a diffrence between order date and shipment date
df3
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df3.dtypes
# Out:
# Row ID                            int64
# Order Priority                   object
# Discount                        float64
# Unit Price                      float64
# Shipping Cost                   float64
# Customer ID                       int64
# Customer Name                    object
# Ship Mode                        object
# Customer Segment                 object
# Product Category                 object
# Product Sub-Category             object
# Product Container                object
# Product Name                     object
# Product Base Margin             float64
# Region                           object
# State or Province                object
# City                             object
# Postal Code                       int64
# Order Date               datetime64[ns]
# Ship Date                datetime64[ns]
# Profit                          float64
# Quantity ordered new              int64
# Sales                           float64
# ...

# %%
df3['Transction Date']>10
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in _cmp_method(self, other, op)
#    1007         try:
# -> 1008             other = self._validate_comparison_value(other)
#    1009         except InvalidComparison:
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in _validate_comparison_value(self, other)
#     545         elif not is_list_like(other):
# --> 546             raise InvalidComparison(other)
#     547
#
# InvalidComparison: 10
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16288/2445635948.py in <module>
# ----> 1 df3['Transction Date']>10
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
# ...

# %%
df3['Transction Date'] = df3['Transction Date'].apply(lambda x: x.value)

# %%
df3.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
df3[df3['Transction Date']>10]['Order ID'] #base on question number 8 find out for which order id we have shipment duration more than 10 days
# Out:
#       Order ID  Order ID
# 0        88525      65.0
# 1        88522     612.0
# 2        88523     614.0
# 3        88523     678.0
# 5        88524     740.0
# ...        ...       ...
# 9419     87549       NaN
# 9421     87532       NaN
# 9423     87533       NaN
# 9424     87530       NaN
# 9425     87533       NaN
#
# [8301 rows x 2 columns]

# %%
Profit=df3.groupby('City')['Profit'].sum()  #Gorup by region and find out which region is more profitable

# %%
Profit.sort_values(ascending=False)
# Out:
# City
# New York City    38244.196710
# Washington       25515.488720
# Seattle          20705.648127
# Houston          18101.041400
# Portland         16994.990305
#                      ...
# Bozeman         -12362.124368
# Durango         -13753.102596
# Hattiesburg     -14441.297580
# Galesburg       -15290.478000
# Gastonia        -15865.728500
# Name: Profit, Length: 1424, dtype: float64

# %%
Discount=df3.groupby('City')['Discount'].sum()

# %%
Discount.sort_values(ascending=False)   #Try to find out overalll in which country we are giving more didscount
# Out:
# City
# Los Angeles        10.37
# New York City      10.16
# Chicago             4.83
# Seattle             4.47
# Boston              3.79
#                    ...
# Billerica           0.00
# North Kingstown     0.00
# Toms River          0.00
# Acton               0.00
# Wallingford         0.00
# Name: Discount, Length: 1424, dtype: float64

# %%
df3['Postal Code'].unique()  #Give me a list of unique postal code
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
#which customer segement is more profitalble find it out

Profitable_Customer_Segment=df.groupby('Customer Segment')['Profit'].sum()

# %%
Profitable_Customer_Segment.sort_values(ascending=False)
# Out:
# Customer Segment
# Corporate         505538.627783
# Small Business    316474.592482
# Home Office       283869.553814
# Consumer          206559.625348
# Name: Profit, dtype: float64

# %%
#try to find out the 10th most loss making product catagory

Loss_Making_Product=df3.groupby('Product Category')['Profit'].count()

# %%
Loss_Making_Product   #We do not have total 10 products
# Out:
# Product Category
# Furniture          1933
# Office Supplies    5181
# Technology         2312
# Name: Profit, dtype: int64

# %%
df3[(df3['Status']=="Returned") & (df3['Transction Date'])<15][['Product Category','Order ID', 'City']]   #Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
# Out:
#      Product Category  Order ID  Order ID        City
# 0     Office Supplies     88525      65.0     Addison
# 1     Office Supplies     88522     612.0   Anacortes
# 2     Office Supplies     88523     614.0   Anacortes
# 3     Office Supplies     88523     678.0   Anacortes
# 4          Technology     88523     710.0   Anacortes
# ...               ...       ...       ...         ...
# 9421  Office Supplies     87532       NaN  Charleston
# 9422  Office Supplies     87532       NaN  Charleston
# 9423        Furniture     87533       NaN  Charleston
# 9424        Furniture     87530       NaN    Cheyenne
# 9425  Office Supplies     87533       NaN    Cheyenne
#
# [9426 rows x 4 columns]
